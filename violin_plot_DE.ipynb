# %%
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#               gene                    samplename  normalized_counts  group
# 0  ENSG00000101441  TCGA-UY-A8OC-01A-11R-A36F-07           4.126001  Tumor
# 1  ENSG00000123500  TCGA-UY-A8OC-01A-11R-A36F-07          11.238452  Tumor
# 2  ENSG00000126890  TCGA-UY-A8OC-01A-11R-A36F-07           3.683202  Tumor
# 3  ENSG00000145321  TCGA-UY-A8OC-01A-11R-A36F-07           3.683202  Tumor
# 4  ENSG00000159217  TCGA-UY-A8OC-01A-11R-A36F-07           7.926742  Tumor

# %%
figure(num=None, figsize=(14, 6), dpi=300, facecolor='w', edgecolor='k')

graph = sns.violinplot(x="gene", y="normalized_counts", hue="group",

                    data=data, palette="Set3", split=True)
graph.set_xticklabels(graph.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'ENSG00000101441'),
#  Text(0, 0, 'ENSG00000123500'),
#  Text(0, 0, 'ENSG00000126890'),
#  Text(0, 0, 'ENSG00000145321'),
#  Text(0, 0, 'ENSG00000159217'),
#  Text(0, 0, 'ENSG00000163586'),
#  Text(0, 0, 'ENSG00000167754'),
#  Text(0, 0, 'ENSG00000170373'),
#  Text(0, 0, 'ENSG00000171560'),
#  Text(0, 0, 'ENSG00000171564'),
#  Text(0, 0, 'ENSG00000181433'),
#  Text(0, 0, 'ENSG00000184330'),
#  Text(0, 0, 'ENSG00000185479'),
#  Text(0, 0, 'ENSG00000186847'),
#  Text(0, 0, 'ENSG00000187172'),
#  Text(0, 0, 'ENSG00000203857'),
#  Text(0, 0, 'ENSG00000204019'),
#  Text(0, 0, 'ENSG00000228437'),
#  Text(0, 0, 'ENSG00000229035'),
#  Text(0, 0, 'ENSG00000233532'),
#  Text(0, 0, 'ENSG00000237412'),
#  Text(0, 0, 'ENSG00000250920'),
#  Text(0, 0, 'ENSG00000260887'),
#  Text(0, 0, 'ENSG00000266976'),
#  Text(0, 0, 'ENSG00000269586')]
